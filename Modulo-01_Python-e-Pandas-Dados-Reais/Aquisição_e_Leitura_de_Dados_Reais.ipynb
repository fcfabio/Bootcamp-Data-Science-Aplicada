# %% [markdown]
# # Aquisição e Leitura de Dados Reais

# %% [markdown]
# ## Produção hospitalar e Pandas
#
# Exploração dos dados do datasus 2008 em diante.
# Dados extraídos de http://tabnet.datasus.gov.br/cgi/tabcgi.exe?sih/cnv/qiuf.def

# %%
import pandas as pd

# %%
arquivo_dados = "arquivo_dados.csv"

# %%
dados = pd.read_csv(arquivo_dados)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-2dee441e8b06> in <module>
# ----> 1 dados = pd.read_csv(arquivo_dados)
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 57: invalid continuation byte

# %% [markdown]
# Muitos locais utilizam padrão de encoding ISO-8859-1, portanto devemos especificar durante abertura do arquivo:

# %%
dados = pd.read_csv(arquivo_dados, encoding = "ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-857b7de51fa7> in <module>
# ----> 1 dados = pd.read_csv(arquivo_dados, encoding = "ISO-8859-1")
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~\Anaconda3\envs\tf_gpu3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 154

# %% [markdown]
# Não foi possível tokenizar os dados, pois a separação do arquivo é com ponto e vírgula, e não é separado por vírgulas.
# Nosso arquivo possui algumas linhas que não são dados.

# %%
dados = pd.read_csv(arquivo_dados, encoding = "ISO-8859-1", skiprows = 3, sep = ";")

# %% [markdown]
# skiprows pula linhas do arquivo.

# %%
dados
# Out:
#                                  Unidade da Federação      2008/Jan  \
# 0                                         11 Rondônia    1388528,39
# 1                                             12 Acre     902416,00
# 2                                         13 Amazonas    4735529,42
# 3                                          14 Roraima     657889,53
# 4                                             15 Pará   18864744,11
# 24    8684882,23    7886243,14    8794109,79    9231645,40   10221763,77
# 25   22258668,68   21442515,75   20921212,45   21615970,67   18270043,87
# 26    7632480,67    9647203,26   11098732,99   12891719,72   12850125,67
# 27  613174269,21  664043058,38  686662861,42  715803639,49  752181563,64
# 28           NaN           NaN           NaN           NaN           NaN
# 29           NaN           NaN           NaN           NaN           NaN
# 30           NaN           NaN           NaN           NaN           NaN
# 31           NaN           NaN           NaN           NaN           NaN
# 32           NaN           NaN           NaN           NaN           NaN
# 33           NaN           NaN           NaN           NaN           NaN
# 34           NaN           NaN           NaN           NaN           NaN
#
#         2008/Jul      2008/Ago      2008/Set  ...       2019/Dez  \
# 0     3065279,01    3231494,61    3117178,63  ...     8085025,66
# 1     2511754,59    2089107,14    2275708,53  ...     2874871,28
# 2     9368858,72    9352532,70    9363099,35  ...    14346553,60
# 3      996693,09     894271,18     910424,17  ...     3097113,21
# 4    24002223,56   23341218,03   25172261,32  ...    35925899,01
# 5     1426659,48    1475551,38    1651341,43  ...     2296699,42
# 6     5445602,28    5413710,38    5596669,50  ...     7210731,09
# 7    15784899,40   15195312,89   14951277,75  ...    29445106,74
# 8    11040107,92   10549176,40   10899198,97  ...    17641837,23
# 9    30925391,36   27851438,72   30362719,90  ...    50834117,85
# 10   11386349,96   10640817,47   11336030,28  ...    20947198,83
# 11   12755413,77   12872578,37   12558296,11  ...    18232875,68
# 12   32685640,76   35457038,66   33668261,46  ...    65707157,96
# 13    9887061,61    9373432,00    9563580,50  ...    16954034,95
# 14    5521904,44    5238398,50    5187912,19  ...     8463411,72
# 15   47481695,17   46931248,28   44883379,31  ...    71008469,66
# 16   85360064,11   84722528,10   84601757,95  ...   153880105,15
# 17   13035374,08   12588595,77   12727433,30  ...    27447261,00
# 18   49872379,35   50912706,60   49270352,76  ...    78579849,30
# 19  194398399,48  184854516,35  188636359,55  ...   284749770,52
# 20   58094241,83   56982774,90   57549082,26  ...   117896293,89
# 21   30789135,84   31250854,33   30019676,93  ...    62332394,92
# 22   56636376,98   56113054,70   55356224,30  ...    90775418,13
# 23   10249299,82    9671553,45   10218511,05  ...    17895244,76
# 24    9163314,28    9243148,81    9052354,89  ...    15029205,51
# 25   20540517,13   20650730,67   20868443,56  ...    34873099,14
# 26   12565646,74   13710857,89   13165106,20  ...    18769437,77
# 27  764990284,76  750608648,28  752962642,15  ...  1275299183,98
# 28           NaN           NaN           NaN  ...            NaN
# 29           NaN           NaN           NaN  ...            NaN
# 30           NaN           NaN           NaN  ...            NaN
# 31           NaN           NaN           NaN  ...            NaN
# 32           NaN           NaN           NaN  ...            NaN
# 33           NaN           NaN           NaN  ...            NaN
# 34           NaN           NaN           NaN  ...            NaN
#
#          2020/Jan       2020/Fev       2020/Mar       2020/Abr       2020/Mai  \
# 0      9221412,18     7493310,88     8092260,11     7273843,63     7652120,28
# 1      3331803,55     3417691,07     3076003,20     2286642,60     2896340,24
# 2     16018459,07    14913745,37    15068304,35    13509579,29    19658585,46
# 17    28942645,28    33290880,33    32188873,88    3139189177,73
# 18    91507444,94    98722687,54    95274486,35    9696364115,11
# 19   306425499,30   366721243,71   346512263,17   38929549655,89
# 20    96977288,37   109658360,43   129375911,54   13786964617,27
# 21    54457911,56    63467828,84    63972379,36    7324100054,96
# 22    86051002,13   100531035,83   101374341,51   11958647088,33
# 23    17331445,92    18755557,92    19241624,02    2172157981,36
# 24    13151005,63    16371639,49    17790649,87    2036923784,59
# 25    35701473,15    39405050,36    43984702,05    4657350310,70
# 26    22704335,27    25269773,34    26526196,39    2429933198,76
# 27  1277909850,50  1471378812,46  1469130891,63  161830758554,04
# 28            NaN            NaN            NaN              NaN
# 29            NaN            NaN            NaN              NaN
# 30            NaN            NaN            NaN              NaN
# 31            NaN            NaN            NaN              NaN
# 32            NaN            NaN            NaN              NaN
# 33            NaN            NaN            NaN              NaN
# 34            NaN            NaN            NaN              NaN
#
# [35 rows x 154 columns]

# %% [markdown]
# Podemos verificar que o rodapé do arquivo também não é composto de dados.
# Com isso adicionaremos um comando para evitar as linhas do rodapé: "skipfooter"

# %%
dados = pd.read_csv(arquivo_dados, encoding = "ISO-8859-1", skiprows = 3, sep = ";", skipfooter = 12)
# Out:
# C:\Users\fcfab\Anaconda3\envs\tf_gpu3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
dados
# Out:
#       Unidade da Federação     2008/Jan      2008/Fev      2008/Mar  \
# 0              11 Rondônia   1388528,39    2931283,42    1541682,52
# 1                  12 Acre    902416,00    1497206,26    1794028,48
# 2              13 Amazonas   4735529,42    7118990,57    8196635,49
# 3               14 Roraima    657889,53     777939,31     718688,03
# 4                  15 Pará  18864744,11   19553758,20   21937342,70
# 5                 16 Amapá   1120973,34    1268740,33     974651,24
# 6             17 Tocantins   3441592,69    4985688,85    6205612,60
# 7              21 Maranhão  10723506,39   13559679,41   13985142,36
# 8                 22 Piauí   7985142,43   10079928,25   10298372,45
# 9                 23 Ceará  15539821,90   25735101,55   28724625,75
# 10  24 Rio Grande do Norte   5947814,08    9509755,83   10352238,59
# 11              25 Paraíba  10723002,45   11386274,47   12053643,87
# 12           26 Pernambuco  14393949,89   24181400,95   29991302,71
# 13              27 Alagoas   6243726,32    8376622,16    8408336,22
# 14              28 Sergipe   2780750,11    3676483,16    5051473,61
# 15                29 Bahia  21211522,47   28189304,95   34181483,52
# 16         31 Minas Gerais  45671659,76   70194037,10   79231336,95
# 17       32 Espírito Santo   5456723,98    9102212,86   10249595,97
# 18       33 Rio de Janeiro  23025258,52   28394310,93   44567062,94
# 19            35 São Paulo  91678473,48  148677526,82  156087269,23
# 20               41 Paraná  38266347,46   55384670,52   53801318,85
# 21       42 Santa Catarina  16504913,45   25651429,11   26743524,89
# 22    43 Rio Grande do Sul  30931325,46   57363420,01   51547794,07
# 23   50 Mato Grosso do Sul   5377392,11    7002472,61    8423933,19
#
#              Total
# 0     929129659,72
# 1     420668039,63
# 2    1771654871,23
# 3     305010883,18
# 4    4437115730,71
# 5     291637984,75
# 6     999998621,85
# 7    3632860959,84
# 8    2130616492,35
# 9    6197357245,98
# 10   2477372149,60
# 11   2470550104,25
# 12   8046954289,39
# 13   2104405303,11
# 14   1130337049,71
# 15   9193802684,16
# 16  19160106499,88
# 17   3139189177,73
# 18   9696364115,11
# 19  38929549655,89
# 20  13786964617,27
# 21   7324100054,96
# 22  11958647088,33
# 23   2172157981,36
# 24   2036923784,59
# 25   4657350310,70
# 26   2429933198,76
#
# [27 rows x 154 columns]

# %% [markdown]
# Mostrar apenas cabeçalho:

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1              12 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2          13 Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3           14 Roraima    657889,53    777939,31    718688,03    839994,39
# 4              15 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2019/Dez     2020/Jan     2020/Fev     2020/Mar     2020/Abr  \
# 0   8085025,66   9221412,18   7493310,88   8092260,11   7273843,63
# 1   2874871,28   3331803,55   3417691,07   3076003,20   2286642,60
# 2  14346553,60  16018459,07  14913745,37  15068304,35  13509579,29
# 3   3097113,21   3059823,80   2912519,98   2937346,43   2868820,96
# 4  35925899,01  34345207,63  37384336,94  35512568,15  28217249,66
#
#       2020/Mai     2020/Jun     2020/Jul     2020/Ago          Total
# 0   7652120,28   8725530,68  11152107,08  10285455,78   929129659,72
# 1   2896340,24   3045245,80   3915193,20            -   420668039,63
# 2  19658585,46  20897542,93  19346450,18  14726443,67  1771654871,23
# 3   2752228,26   3401864,29   3015488,30   2826486,18   305010883,18
# 4  32617541,05  41625331,28  38438873,79  39911193,02  4437115730,71
#
# [5 rows x 154 columns]

# %% [markdown]
# Mostrar apenas final da planilha:

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325,46  57363420,01  51547794,07  56673338,49
# 23  50 Mato Grosso do Sul   5377392,11   7002472,61   8423933,19   8797487,68
# 24         51 Mato Grosso   4795299,01   8684882,23   7886243,14   8794109,79
# 25               52 Goiás  15310637,29  22258668,68  21442515,75  20921212,45
# 26    53 Distrito Federal   4745919,19   7632480,67   9647203,26  11098732,99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733,07  52413429,62  56636376,98  56113054,70  55356224,30  ...
# 23   9770421,80  10905392,18  10249299,82   9671553,45  10218511,05  ...
# 24   9231645,40  10221763,77   9163314,28   9243148,81   9052354,89  ...
# 25  21615970,67  18270043,87  20540517,13  20650730,67  20868443,56  ...
# 26  12891719,72  12850125,67  12565646,74  13710857,89  13165106,20  ...
#
#        2019/Dez     2020/Jan     2020/Fev      2020/Mar     2020/Abr  \
# 22  90775418,13  94908336,74  91437940,91  102876132,83  83000318,02
# 23  17895244,76  18115134,64  19542439,88   19032785,73  17410262,53
# 24  15029205,51  15249241,20  15046851,63   14886817,29  12546999,04
# 25  34873099,14  35775375,69  35005746,36   34793993,14  30896577,34
# 26  18769437,77  22341629,09  20643441,06   22947163,99  21536505,16
#
#        2020/Mai     2020/Jun      2020/Jul      2020/Ago           Total
# 22  82381774,95  86051002,13  100531035,83  101374341,51  11958647088,33
# 23  17913161,92  17331445,92   18755557,92   19241624,02   2172157981,36
# 24  13604225,34  13151005,63   16371639,49   17790649,87   2036923784,59
# 25  34305180,56  35701473,15   39405050,36   43984702,05   4657350310,70
# 26  19058243,91  22704335,27   25269773,34   26526196,39   2429933198,76
#
# [5 rows x 154 columns]

# %% [markdown]
# Podemos verificar que os dados da tabela são compostos por strings e não por números, já que os números são separados por vírgula ao invés de ponto.
# Devemos ler o arquivo indicando que o separador é vírgula.

# %%
dados = pd.read_csv(arquivo_dados, encoding = "ISO-8859-1", skiprows = 3, sep = ";", skipfooter = 12,
                   thousands = ".", decimal = ",")
dados.head()
# Out:
# C:\Users\fcfab\Anaconda3\envs\tf_gpu3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2019/Dez     2020/Jan     2020/Fev     2020/Mar     2020/Abr  \
# 0   8085025.66   9221412.18   7493310.88   8092260.11   7273843.63
# 1   2874871.28   3331803.55   3417691.07   3076003.20   2286642.60
# 2  14346553.60  16018459.07  14913745.37  15068304.35  13509579.29
# 3   3097113.21   3059823.80   2912519.98   2937346.43   2868820.96
# 4  35925899.01  34345207.63  37384336.94  35512568.15  28217249.66
#
#       2020/Mai     2020/Jun     2020/Jul     2020/Ago         Total
# 0   7652120.28   8725530.68  11152107.08  10285455.78  9.291297e+08
# 1   2896340.24   3045245.80   3915193.20            -  4.206680e+08
# 2  19658585.46  20897542.93  19346450.18  14726443.67  1.771655e+09
# 3   2752228.26   3401864.29   3015488.30   2826486.18  3.050109e+08
# 4  32617541.05  41625331.28  38438873.79  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
#imprimir a média
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Abr    4.101366e+07
# 2020/Mai    4.419363e+07
# 2020/Jun    4.732999e+07
# 2020/Jul    5.449551e+07
# Total       5.993732e+09
# Length: 151, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %% [markdown]
# Vamos configurar o pandas para exibir números com apenas duas casas decimais e evitar notação científica:

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %% [markdown]
# Como selecionar um único valor dentro do dataframe?
#
#     Exemplo: Agosto/2008 - dados["2008/Ago"] retornará uma série.

# %%
dados["2008/Ago"]
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x="Unidade da Federação", y = "2008/Ago", kind="bar")

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
#axis
ax = dados.plot(x="Unidade da Federação", y = "2008/Ago", kind="bar", figsize=(10,5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# ## Desafio01: escolher um título mais descritivo que passe a mensagem adequada

# %%
#axis
ax = dados.plot(x="Unidade da Federação", y = "2008/Ago", kind="bar", figsize=(10,5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gastos totais por unidade da federação: Agosto/2008")
plt.show()

# %% [markdown]
# ## Desafio02: faça a mesma análise para o mês mais recente

# %%
dados["2020/Ago"].unique()
# Out:
# array(['10285455.78', '-', '14726443.67', '2826486.18', '39911193.02',
#        '2942273.94', '8240261.38', '28587541.78', '23210624.20',
#        '59808605.59', '24929930.72', '22130016.81', '75704177.72',
#        '19754741.78', '11014180.89', '80793117.08', '168024412.95',
#        '32188873.88', '95274486.35', '346512263.17', '129375911.54',
#        '63972379.36', '101374341.51', '19241624.02', '17790649.87',
#        '43984702.05', '26526196.39'], dtype=object)

# %%
dados["2020/Ago"] = pd.to_numeric(dados["2020/Ago"], errors='coerce')
dados.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 4              15 Pará 18864744.11 19553758.20 21937342.70 20842829.69
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 2  7831399.90  8477273.62  9368858.72  9352532.70  9363099.35  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 4 23249952.88 23240687.56 24002223.56 23341218.03 25172261.32  ...
#
#      2019/Dez    2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai  \
# 0  8085025.66  9221412.18  7493310.88  8092260.11  7273843.63  7652120.28
# 1  2874871.28  3331803.55  3417691.07  3076003.20  2286642.60  2896340.24
# 2 14346553.60 16018459.07 14913745.37 15068304.35 13509579.29 19658585.46
# 3  3097113.21  3059823.80  2912519.98  2937346.43  2868820.96  2752228.26
# 4 35925899.01 34345207.63 37384336.94 35512568.15 28217249.66 32617541.05
#
#      2020/Jun    2020/Jul    2020/Ago         Total
# 0  8725530.68 11152107.08 10285455.78  929129659.72
# 1  3045245.80  3915193.20         nan  420668039.63
# 2 20897542.93 19346450.18 14726443.67 1771654871.23
# 3  3401864.29  3015488.30  2826486.18  305010883.18
# 4 41625331.28 38438873.79 39911193.02 4437115730.71
#
# [5 rows x 154 columns]

# %%
#axis
ax = dados.plot(x="Unidade da Federação", y = "2020/Ago", kind="bar", figsize=(10,5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gastos totais por unidade da federação: Agosto/2020")
plt.show()

# %% [markdown]
# ## Gráficos

# %% [markdown]
# Utilizando arquivo de data de processamento dos pagamentos:

# %%
dados2 = pd.read_csv(arquivo_dados, encoding = "ISO-8859-1", skiprows = 3, sep = ";", skipfooter = 12,
                   thousands = ".", decimal = ",")
dados2.head()
# Out:
# C:\Users\fcfab\Anaconda3\envs\tf_gpu3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 4              15 Pará 18864744.11 19553758.20 21937342.70 20842829.69
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 2  7831399.90  8477273.62  9368858.72  9352532.70  9363099.35  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 4 23249952.88 23240687.56 24002223.56 23341218.03 25172261.32  ...
#
#      2019/Dez    2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai  \
# 0  8085025.66  9221412.18  7493310.88  8092260.11  7273843.63  7652120.28
# 1  2874871.28  3331803.55  3417691.07  3076003.20  2286642.60  2896340.24
# 2 14346553.60 16018459.07 14913745.37 15068304.35 13509579.29 19658585.46
# 3  3097113.21  3059823.80  2912519.98  2937346.43  2868820.96  2752228.26
# 4 35925899.01 34345207.63 37384336.94 35512568.15 28217249.66 32617541.05
#
#      2020/Jun    2020/Jul     2020/Ago         Total
# 0  8725530.68 11152107.08  10285455.78  929129659.72
# 1  3045245.80  3915193.20            -  420668039.63
# 2 20897542.93 19346450.18  14726443.67 1771654871.23
# 3  3401864.29  3015488.30   2826486.18  305010883.18
# 4 41625331.28 38438873.79  39911193.02 4437115730.71
#
# [5 rows x 154 columns]

# %%
dados2[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  3231494.61  3117178.63
# 1  2089107.14  2275708.53
# 2  9352532.70  9363099.35
# 3   894271.18   910424.17
# 4 23341218.03 25172261.32

# %%
dados2.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
colunas_uteis = dados2.mean().index.to_list()
colunas_uteis.insert(0, "Unidade da Federação")
colunas_uteis
# Out:
# ['Unidade da Federação',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  'Total']

# %%
uteis = dados2[colunas_uteis]
uteis.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima            3059823.80  2912519.98  2937346.43  2868820.96
# 15 Pará              34345207.63 37384336.94 35512568.15 28217249.66
#
#                         2020/Mai    2020/Jun    2020/Jul         Total
# Unidade da Federação
# 11 Rondônia           7652120.28  8725530.68 11152107.08  929129659.72
# 12 Acre               2896340.24  3045245.80  3915193.20  420668039.63
# 13 Amazonas          19658585.46 20897542.93 19346450.18 1771654871.23
# 14 Roraima            2752228.26  3401864.29  3015488.30  305010883.18
# 15 Pará              32617541.05 41625331.28 38438873.79 4437115730.71
#
# [5 rows x 151 columns]

# %%
# Coluna 2019/Ago
uteis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    9170787.53
# 12 Acre        3204998.88
# 13 Amazonas   15787896.78
# 14 Roraima     3788154.80
# 15 Pará       31179893.86
# Name: 2019/Ago, dtype: float64

# %%
#Localiza linha cujo índice se chama 12 Acre
uteis.loc["12 Acre"]
# Out:
# 2008/Jan      902416.00
# 2008/Fev     1497206.26
# 2008/Mar     1794028.48
# 2008/Abr     1730469.42
# 2008/Mai     1819443.92
#                ...
# 2020/Abr     2286642.60
# 2020/Mai     2896340.24
# 2020/Jun     3045245.80
# 2020/Jul     3915193.20
# Total      420668039.63
# Name: 12 Acre, Length: 151, dtype: float64

# %%
uteis = uteis.drop("Total", axis = 1)
uteis.head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2019/Out    2019/Nov  \
# Unidade da Federação                          ...
# 11 Rondônia           3117178.63  3068430.44  ... 10024554.15  9675423.70
# 12 Acre               2275708.53  1923886.57  ...  3124802.29  3021521.75
# 13 Amazonas           9363099.35  8618318.83  ... 15731201.23 15744605.61
# 14 Roraima             910424.17  1191770.32  ...  3113940.14  3157977.67
# 15 Pará              25172261.32 24011712.48  ... 36112567.22 36853237.41
#
#                         2019/Dez    2020/Jan    2020/Fev    2020/Mar  \
# Unidade da Federação
# 11 Rondônia           8085025.66  9221412.18  7493310.88  8092260.11
# 12 Acre               2874871.28  3331803.55  3417691.07  3076003.20
# 13 Amazonas          14346553.60 16018459.07 14913745.37 15068304.35
# 14 Roraima            3097113.21  3059823.80  2912519.98  2937346.43
# 15 Pará              35925899.01 34345207.63 37384336.94 35512568.15
#
#                         2020/Abr    2020/Mai    2020/Jun    2020/Jul
# Unidade da Federação
# 11 Rondônia           7273843.63  7652120.28  8725530.68 11152107.08
# 12 Acre               2286642.60  2896340.24  3045245.80  3915193.20
# 13 Amazonas          13509579.29 19658585.46 20897542.93 19346450.18
# 14 Roraima            2868820.96  2752228.26  3401864.29  3015488.30
# 15 Pará              28217249.66 32617541.05 41625331.28 38438873.79
#
# [5 rows x 150 columns]

# %%
uteis.T.plot(figsize=(10, 6))

# %% [markdown]
# ## Desafio: Colocar a legenda fora do gráfico

# %%
uteis.T.plot(figsize=(10, 6))

plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Desafio: Escolher 5 estados e plotar os gráficos

# %%
uteis.T[["13 Amazonas", "15 Pará", "22 Piauí", "31 Minas Gerais", "35 São Paulo"]].plot(figsize=(10, 6))

plt.show()

# %%
uteis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
# 5 primeiras colunas da matriz transposta
uteis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
#valor referente ao índice das 5 primeiras linhas
uteis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
# 5 primeiras linhas
uteis[:5]
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2019/Out    2019/Nov  \
# Unidade da Federação                          ...
# 11 Rondônia           3117178.63  3068430.44  ... 10024554.15  9675423.70
# 12 Acre               2275708.53  1923886.57  ...  3124802.29  3021521.75
# 13 Amazonas           9363099.35  8618318.83  ... 15731201.23 15744605.61
# 14 Roraima             910424.17  1191770.32  ...  3113940.14  3157977.67
# 15 Pará              25172261.32 24011712.48  ... 36112567.22 36853237.41
#
#                         2019/Dez    2020/Jan    2020/Fev    2020/Mar  \
# Unidade da Federação
# 11 Rondônia           8085025.66  9221412.18  7493310.88  8092260.11
# 12 Acre               2874871.28  3331803.55  3417691.07  3076003.20
# 13 Amazonas          14346553.60 16018459.07 14913745.37 15068304.35
# 14 Roraima            3097113.21  3059823.80  2912519.98  2937346.43
# 15 Pará              35925899.01 34345207.63 37384336.94 35512568.15
#
#                         2020/Abr    2020/Mai    2020/Jun    2020/Jul
# Unidade da Federação
# 11 Rondônia           7273843.63  7652120.28  8725530.68 11152107.08
# 12 Acre               2286642.60  2896340.24  3045245.80  3915193.20
# 13 Amazonas          13509579.29 19658585.46 20897542.93 19346450.18
# 14 Roraima            2868820.96  2752228.26  3401864.29  3015488.30
# 15 Pará              28217249.66 32617541.05 41625331.28 38438873.79
#
# [5 rows x 150 columns]

# %%
#PLotando o gráfico dos 7 primeiros estados da lista
uteis[:7].T.plot(figsize=(10,6))

# %%
import numpy as np

# %%
#definindo seed para que o aleatório seja sempre igual, independente da quantidade de vezes que rodamos

# Exemplo simplificado de como funciona aleatoriedade
# pseudo randomness

# seed = 6987
# random = seed / 10, seed = seed * 2 /3


# random ===> 698...... (seed=4658)
# random ==> 465 (seed = 310)
# random ==> 31

np.random.seed(123456)

#a função "sample" retira uma amostra aleatória dos dados
uteis.sample(n=7)
# Out:
#                          2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Unidade da Federação
# 53 Distrito Federal    4745919.19   7632480.67   9647203.26  11098732.99
# 28 Sergipe             2780750.11   3676483.16   5051473.61   5046063.36
# 35 São Paulo          91678473.48 148677526.82 156087269.23 161227125.43
# 14 Roraima              657889.53    777939.31    718688.03    839994.39
# 16 Amapá               1120973.34   1268740.33    974651.24   1141137.32
# 50 Mato Grosso do Sul  5377392.11   7002472.61   8423933.19   8797487.68
# 42 Santa Catarina     16504913.45  25651429.11  26743524.89  27181488.26
#
#                           2008/Mai     2008/Jun     2008/Jul     2008/Ago  \
# Unidade da Federação
# 53 Distrito Federal    12891719.72  12850125.67  12565646.74  13710857.89
# 28 Sergipe              4741151.56   5401259.63   5521904.44   5238398.50
# 35 São Paulo          187119397.64 187291126.07 194398399.48 184854516.35
# 14 Roraima               862347.96    832440.66    996693.09    894271.18
# 16 Amapá                 866346.18   1440978.95   1426659.48   1475551.38
# 50 Mato Grosso do Sul   9770421.80  10905392.18  10249299.82   9671553.45
# 42 Santa Catarina      26845308.18  29909762.04  30789135.84  31250854.33
#
#                           2008/Set     2008/Out  ...     2019/Out  \
# Unidade da Federação                             ...
# 53 Distrito Federal    13165106.20  15048607.23  ...  17859596.85
# 43 Rio Grande do Sul  90775418.13  94908336.74  91437940.91 102876132.83
# 33 Rio de Janeiro     78579849.30  83186258.72  76116203.22  77004637.47
#
#                          2020/Abr     2020/Mai     2020/Jun     2020/Jul
# Unidade da Federação
# 35 São Paulo         251320040.41 272486957.70 306425499.30 366721243.71
# 31 Minas Gerais      133340766.09 133388804.72 139699763.30 164891823.64
# 41 Paraná             94599403.51 107503816.77  96977288.37 109658360.43
# 43 Rio Grande do Sul  83000318.02  82381774.95  86051002.13 100531035.83
# 33 Rio de Janeiro     71403516.21  85094073.33  91507444.94  98722687.54
#
# [5 rows x 150 columns]

# %%
#Eliminando as primeiras colunas e salvando as demais como colunas de interesse para nossa análise:
colunas_de_interesse = ordenado_por_total.columns[6:]
colunas_de_interesse
# Out:
# Index(['2008/Jul', '2008/Ago', '2008/Set', '2008/Out', '2008/Nov', '2008/Dez',
#        '2009/Jan', '2009/Fev', '2009/Mar', '2009/Abr',
#        ...
#        '2019/Out', '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar',
#        '2020/Abr', '2020/Mai', '2020/Jun', '2020/Jul'],
#       dtype='object', length=144)

# %%
ordenado_por_total = ordenado_por_total[colunas_de_interesse]

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))
plt.show()

# %%
#Melhorando a visualização do eixo Y, exemplo: 35e8 (= 3.500.000.000), vamos dividir todos os valores por 1.000.000
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))
plt.show()

# %%
#Podemos plotar somente parte dos meses:
meses_filtrados = ordenado_por_total.columns[47:140]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10, 6))

# %% [markdown]
# Verifique que nos dois últimos gráficos o eixo Y não se inicia no zero, com isso pode haver uma má interpretação dos gráficos.
# Para evitar comparações errôneas, vamos plotar o gráfico partindo do zero.

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10, 6))
plt.ylim(0, 350)
# Out:
# (0, 350)

# %%
# Podemos plotar somente as últimas 36 colunas:
ordenado_por_total[ordenado_por_total.columns[-36:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0, 350)

# %%
# Ou as últimas 60 colunas:
# Podemos plotar somente as últimas 36 colunas:
ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0, 350)

# %% [markdown]
# Vamos analisar o valor do mês mais recente:

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           366.72
# 31 Minas Gerais        164.89
# 41 Paraná              109.66
# 43 Rio Grande do Sul   100.53
# 33 Rio de Janeiro       98.72
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente.plot()
plt.show()

# %% [markdown]
# E se fosse um gráfico de pizza?

# %%
gastos_do_mais_recente.plot(kind='pie')
plt.show()

# %% [markdown]
# Desvantagens:
# - Legenda está péssima
# - Enorme número de fatias
#
# Vantagem:
# - O gráfico veio ordenado

# %% [markdown]
# E se o gráfico de pizza estivesse desordenado?

# %%
gastos_do_mais_recente.sample(frac=1).plot(kind='pie')
plt.show()

# %% [markdown]
# Desvantagens:
# - Legenda está horrível
# - Número de fatias inacreditável
# - Não dá para saber a ordem
# - Cores repetidas
# - Péssimo para COMPARAR

# %%
# Visualização simples para valores absolutos:
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             366.72
# 31 Minas Gerais          164.89
# 41 Paraná                109.66
# 43 Rio Grande do Sul     100.53
# 33 Rio de Janeiro         98.72
# 29 Bahia                  83.99
# 26 Pernambuco             74.19
# 42 Santa Catarina         63.47
# 23 Ceará                  55.18
# 52 Goiás                  39.41
# 15 Pará                   38.44
# 21 Maranhão               32.94
# 32 Espírito Santo         33.29
# 24 Rio Grande do Norte    26.30
# 25 Paraíba                26.90
# 53 Distrito Federal       25.27
# 50 Mato Grosso do Sul     18.76
# 22 Piauí                  17.87
# 27 Alagoas                18.35
# 51 Mato Grosso            16.37
# 13 Amazonas               19.35
# 28 Sergipe                10.31
# 17 Tocantins               9.13
# 11 Rondônia               11.15
# 12 Acre                    3.92
# 14 Roraima                 3.02
# 16 Amapá                   3.25
# Name: 2020/Jul, dtype: float64

# %%
# Tomando um estado como base para fazer a análise (Minas Gerais), poderemos verificar
# que São Paulo teve mais do que o dobro do gasto

gastos_do_mais_recente / gastos_do_mais_recente.loc["31 Minas Gerais"]
# Out:
# Unidade da Federação
# 35 São Paulo             2.22
# 31 Minas Gerais          1.00
# 41 Paraná                0.67
# 43 Rio Grande do Sul     0.61
# 33 Rio de Janeiro        0.60
# 29 Bahia                 0.51
# 26 Pernambuco            0.45
# 42 Santa Catarina        0.38
# 23 Ceará                 0.33
# 52 Goiás                 0.24
# 15 Pará                  0.23
# 21 Maranhão              0.20
# 32 Espírito Santo        0.20
# 24 Rio Grande do Norte   0.16
# 25 Paraíba               0.16
# 53 Distrito Federal      0.15
# 50 Mato Grosso do Sul    0.11
# 22 Piauí                 0.11
# 27 Alagoas               0.11
# 51 Mato Grosso           0.10
# 13 Amazonas              0.12
# 28 Sergipe               0.06
# 17 Tocantins             0.06
# 11 Rondônia              0.07
# 12 Acre                  0.02
# 14 Roraima               0.02
# 16 Amapá                 0.02
# Name: 2020/Jul, dtype: float64

# %% [markdown]
# Plotando o gráfico de barras com os dados que foram ordenados anteriormente a partir da coluna Total:

# %%
gastos_do_mais_recente.plot(kind='bar', figsize = (10,6))

# %% [markdown]
# Podemos observar que alguns estado estão com gasto mais elevado que seu predecessor e seu sucessor no eixo X, isso se deve à ordenação que fizemos anteriormente, considerando a coluna "Total". Agora vamos ordenar e plotar os valores considerando apenas o mês analisado:

# %%
gastos_do_mais_recente.sort_values(ascending=False).plot(kind='bar', figsize = (10,6))
